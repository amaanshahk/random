# %%
import cv2
import mediapipe as mp
import numpy as np

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

def calculate_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)

    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)

    if angle > 180.0:
        angle = 360 - angle

    return angle

def count_rep(counter, stage, angle, up_threshold, down_threshold):
    if angle > up_threshold:
        stage = "up"
    if angle < down_threshold and stage == 'up':
        stage = "down"
        counter += 1
        print("Rep Count:", counter)
    return counter, stage

cap = cv2.VideoCapture(0)

# Squat counter variables
squat_counter = 0
squat_stage = None

# Thresholds for squat detection
squat_up_threshold = 170
squat_down_threshold = 80  # Adjusted down threshold

# Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()

        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection
        results = pose.process(image)

        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark

            # Squat tracking for knee
            shoulder_l = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                           landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            hip_l = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,
                     landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            knee_l = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,
                      landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
            heel_l = [landmarks[mp_pose.PoseLandmark.LEFT_HEEL.value].x,
                       landmarks[mp_pose.PoseLandmark.LEFT_HEEL.value].y]

            angle_lk = int(calculate_angle(hip_l, knee_l, heel_l))

            shoulder_r = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,
                           landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            hip_r = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,
                     landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            knee_r = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,
                      landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            heel_r = [landmarks[mp_pose.PoseLandmark.RIGHT_HEEL.value].x,
                       landmarks[mp_pose.PoseLandmark.RIGHT_HEEL.value].y]

            angle_rk = int(calculate_angle(hip_r, knee_r, heel_r))

            avg_knee_angle = (angle_lk + angle_rk) / 2

            # Squat tracking for hip
            angle_lh = int(calculate_angle(shoulder_l, hip_l, knee_l))
            angle_rh = int(calculate_angle(shoulder_r, hip_r, knee_r))
            avg_hip_angle = (angle_lh + angle_rh) / 2

            # Squat counting based on knee and hip angles
            squat_counter, squat_stage = count_rep(squat_counter, squat_stage, avg_knee_angle,
                                                   squat_up_threshold, squat_down_threshold)

            # Visualize angles at knee points
            cv2.putText(image, 'Left Knee Angle: {:.2f}'.format(angle_lk), (10, 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

            cv2.putText(image, 'Right Knee Angle: {:.2f}'.format(angle_rk), (10, 60),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

            # Visualize angles at hip points
            cv2.putText(image, 'Left Hip Angle: {:.2f}'.format(angle_lh), (10, 90),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

            cv2.putText(image, 'Right Hip Angle: {:.2f}'.format(angle_rh), (10, 120),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

        except:
            pass

        # Render squat counter
        cv2.putText(image, 'Squat Reps: ' + str(squat_counter), (10, 150),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                   mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                   mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                                   )

        cv2.putText(image, str(angle_lk),
                    tuple(np.multiply(knee_l, [640, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.putText(image, str(angle_rk),
                    tuple(np.multiply(knee_r, [640, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.putText(image, str(angle_lh),
                    tuple(np.multiply(hip_l, [640, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.putText(image, str(angle_rh),
                    tuple(np.multiply(hip_r, [640, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2, cv2.LINE_AA)

        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1704171868.758281   13430 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1704171868.759069   14034 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 23.0.4-0ubuntu1~22.04.1), renderer: Mesa Intel(R) UHD Graphics (ICL GT1)
# Rep Count: 1

# %%
# !pip install mediapipe opencv-python ipywidgets voila
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mediapipe in /home/amaanshahk/.local/lib/python3.10/site-packages (0.10.8)
# Requirement already satisfied: opencv-python in /home/amaanshahk/.local/lib/python3.10/site-packages (4.8.1.78)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.1-py3-none-any.whl (139 kB)
# Collecting voila
#   Downloading voila-0.5.5-py3-none-any.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 1.1 MB/s eta 0:00:00m eta 0:00:010:00:010m
# Requirement already satisfied: absl-py in /home/amaanshahk/.local/lib/python3.10/site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: attrs>=19.1.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/lib/python3/dist-packages (from mediapipe) (3.12.4)
# Requirement already satisfied: sounddevice>=0.4.4 in /home/amaanshahk/.local/lib/python3.10/site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: matplotlib in /home/amaanshahk/.local/lib/python3.10/site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in /home/amaanshahk/.local/lib/python3.10/site-packages (from mediapipe) (1.26.2)
# Requirement already satisfied: opencv-contrib-python in /home/amaanshahk/.local/lib/python3.10/site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: flatbuffers>=2.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: traitlets>=4.3.1 in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipywidgets) (5.13.0)
# Requirement already satisfied: comm>=0.1.3 in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.0)
# Collecting jupyterlab-widgets~=3.0.9
#   Using cached jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
# Requirement already satisfied: ipython>=6.1.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipywidgets) (8.18.0)
# Collecting widgetsnbextension~=4.0.9
#   Using cached widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from voila) (2.25.2)
# Collecting nbclient<0.8,>=0.4.0
#   Downloading nbclient-0.7.4-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 639.1 kB/s eta 0:00:0036m0:00:010:00:01
# Requirement already satisfied: jupyter-server<3,>=2.0.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from voila) (2.10.1)
# Requirement already satisfied: jupyter-core>=4.11.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from voila) (5.5.0)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /home/amaanshahk/.local/lib/python3.10/site-packages (from voila) (7.11.0)
# Collecting websockets>=9.0
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 KB 722.3 kB/s eta 0:00:001.7 MB/s eta 0:00:01
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in /home/amaanshahk/.local/lib/python3.10/site-packages (from voila) (8.6.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.17.2)
# Requirement already satisfied: stack-data in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: decorator in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.41)
# Requirement already satisfied: exceptiongroup in /home/amaanshahk/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: tornado>=6.2 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (6.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-client<9,>=7.4.4->voila) (25.1.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.11.0->voila) (4.0.0)
# Requirement already satisfied: nbformat>=5.3.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (5.9.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (4.1.0)
# Requirement already satisfied: argon2-cffi in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (23.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.18.0)
# Requirement already satisfied: websocket-client in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (1.6.4)
# Requirement already satisfied: jinja2 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (3.1.2)
# Requirement already satisfied: packaging in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (23.2)
# Requirement already satisfied: send2trash>=1.8.2 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (1.8.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.9.0)
# Requirement already satisfied: prometheus-client in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.19.0)
# Requirement already satisfied: overrides in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (7.4.0)
# Requirement already satisfied: jupyter-server-terminals in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.0.0->voila) (0.4.4)
# Requirement already satisfied: json5>=0.9.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.14)
# Requirement already satisfied: babel>=2.10 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.13.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.20.0)
# Requirement already satisfied: requests>=2.31 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.31.0)
# Requirement already satisfied: bleach!=5.0.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (6.1.0)
# Requirement already satisfied: jupyterlab-pygments in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (3.0.2)
# Requirement already satisfied: beautifulsoup4 in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (4.12.2)
# Requirement already satisfied: tinycss2 in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (2.1.3)
# Requirement already satisfied: defusedxml in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: CFFI>=1.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from matplotlib->mediapipe) (4.45.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/amaanshahk/.local/lib/python3.10/site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/amaanshahk/.local/lib/python3.10/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: pillow>=8 in /usr/lib/python3/dist-packages (from matplotlib->mediapipe) (9.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->mediapipe) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/amaanshahk/.local/lib/python3.10/site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: sniffio>=1.1 in /home/amaanshahk/.local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.0->voila) (3.3)
# Requirement already satisfied: webencodings in /home/amaanshahk/.local/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from bleach!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.16.0)
# Requirement already satisfied: pycparser in /home/amaanshahk/.local/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.13.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.31.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2023.11.1)
# Requirement already satisfied: pyyaml>=5.3 in /usr/lib/python3/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (5.4.1)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/amaanshahk/.local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.0.0->voila) (0.1.4)
# Requirement already satisfied: fastjsonschema in /home/amaanshahk/.local/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.0.0->voila) (2.19.0)
# Requirement already satisfied: wcwidth in /home/amaanshahk/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2020.6.20)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (1.26.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/amaanshahk/.local/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (3.3.2)
# Requirement already satisfied: ptyprocess in /usr/lib/python3/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.0.0->voila) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/amaanshahk/.local/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.0.0->voila) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/amaanshahk/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.5)
# Requirement already satisfied: pure-eval in /home/amaanshahk/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: uri-template in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (1.3.0)
# Requirement already satisfied: fqdn in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2.4)
# Requirement already satisfied: webcolors>=1.11 in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (1.13)
# Requirement already satisfied: isoduration in /home/amaanshahk/.local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (20.11.0)
# Requirement already satisfied: arrow>=0.15.0 in /home/amaanshahk/.local/lib/python3.10/site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/amaanshahk/.local/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2.8.19.14)
# Installing collected packages: widgetsnbextension, websockets, jupyterlab-widgets, ipywidgets, nbclient, voila
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.9.0
#     Uninstalling nbclient-0.9.0:
#       Successfully uninstalled nbclient-0.9.0
# Successfully installed ipywidgets-8.1.1 jupyterlab-widgets-3.0.9 nbclient-0.7.4 voila-0.5.5 websockets-12.0 widgetsnbextension-4.0.9

# %%
voila squats_final.ipynb
# Out:
#   Cell In[3], line 1
#     voila squats_final.ipynb
#           ^
# SyntaxError: invalid syntax
